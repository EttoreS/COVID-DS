# %% [markdown]
# # COVID BRASIL

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Read data

# %%
# dataset = pd.read_csv('dados/HIST_PAINEL_COVIDBR_04fev2021.csv', sep=';')
# dataset
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 1770850  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1770851  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1770852  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1770853  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 1770854  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
# dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770855 entries, 0 to 1770854
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   regiao                  object
#  1   estado                  object
#  2   municipio               object
#  3   coduf                   int64
#  4   codmun                  float64
#  5   codRegiaoSaude          float64
#  6   nomeRegiaoSaude         object
#  7   data                    object
#  8   semanaEpi               int64
#  9   populacaoTCU2019        float64
#  10  casosAcumulado          int64
#  11  casosNovos              int64
#  12  obitosAcumulado         int64
#  13  obitosNovos             int64
#  14  Recuperadosnovos        float64
#  15  emAcompanhamentoNovos   float64
#  16  interior/metropolitana  float64
# dtypes: float64(6), int64(6), object(5)
# memory usage: 229.7+ MB

# %% [markdown]
# ## Dados só Brasil

# %%
# brasil_data = dataset.loc[dataset['regiao'] == 'Brasil']
# brasil_data
# Out:
#      regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4    Brasil    NaN       NaN     76     NaN             NaN             NaN
# ..      ...    ...       ...    ...     ...             ...             ...
# 343  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 344  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 345  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 346  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 347  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
# ...

# %%
#brasil_data.to_csv('dados/covid_brasil.csv', sep=';', index=False )
dataset = pd.read_csv('dados/covid_brasil.csv', sep=';')
dataset

# %%
brasil_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348 entries, 0 to 347
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   regiao                  348 non-null    object
#  1   estado                  0 non-null      object
#  2   municipio               0 non-null      object
#  3   coduf                   348 non-null    int64
#  4   codmun                  0 non-null      float64
#  5   codRegiaoSaude          0 non-null      float64
#  6   nomeRegiaoSaude         0 non-null      object
#  7   data                    348 non-null    object
#  8   semanaEpi               348 non-null    int64
#  9   populacaoTCU2019        348 non-null    float64
#  10  casosAcumulado          348 non-null    int64
#  11  casosNovos              348 non-null    int64
#  12  obitosAcumulado         348 non-null    int64
#  13  obitosNovos             348 non-null    int64
# ...

# %%
brasil_data.isna()
# Out:
#      regiao  estado  municipio  coduf  codmun  codRegiaoSaude  \
# 0     False    True       True  False    True            True
# 1     False    True       True  False    True            True
# 2     False    True       True  False    True            True
# 3     False    True       True  False    True            True
# 4     False    True       True  False    True            True
# ..      ...     ...        ...    ...     ...             ...
# 343   False    True       True  False    True            True
# 344   False    True       True  False    True            True
# 345   False    True       True  False    True            True
# 346   False    True       True  False    True            True
# 347   False    True       True  False    True            True
#
#      nomeRegiaoSaude   data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 0               True  False      False             False           False
# ...

# %% [markdown]
# ## Remove nan data

# %%
data = brasil_data[[
    'regiao',
    'data',
    'populacaoTCU2019',
    'casosAcumulado',
    'casosNovos',
    'obitosAcumulado',
    'obitosNovos',
]]

brasil_clear_data = pd.DataFrame(data.fillna(0))
brasil_clear_data
# Out:
#      regiao        data  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0    Brasil  2020-02-25       210147125.0               0           0
# 1    Brasil  2020-02-26       210147125.0               1           1
# 2    Brasil  2020-02-27       210147125.0               1           0
# 3    Brasil  2020-02-28       210147125.0               1           0
# 4    Brasil  2020-02-29       210147125.0               2           1
# ..      ...         ...               ...             ...         ...
# 343  Brasil  2021-01-31       210147125.0         9204731       27756
# 344  Brasil  2021-02-01       210147125.0         9229322       24591
# 345  Brasil  2021-02-02       210147125.0         9283418       54096
# 346  Brasil  2021-02-03       210147125.0         9339420       56002
# 347  Brasil  2021-02-04       210147125.0         9396293       56873
#
#      obitosAcumulado  obitosNovos
# 0                  0            0
# 1                  0            0
# ...
